# %% [markdown]
# # Beispiele zum [CAS Cloud and Platform Manager](https://www.hslu.ch/de-ch/informatik/weiterbildung/technologies-and-methods/cas-cloud/)
#
# Mit Cloud-Expertise die Digitalisierung mitgestalten.

# %% [markdown]
# ## Übungen
#
# ### Internet der Dinge (IoT)
#
# * [M5Stack IDE](https://flow.m5stack.com/)
#
# ### IoT Protokolle
#
# * [MQTT Subscriber starten](../../duk/data/jupyter/functions/mqtt-iot-subscriber/mqtt-iot-subscriber-1.0.0.ipynb)
#
# ### Backend: Microservices und Infrastruktur
#
# * [Applikationen deployen (GitOps)](../../k8sd2o/data/00-common/GitOps/ArgoCD.ipynb)
#
# ### Operator Pattern
#
# * [IIoT MQTT Operator](../../k8sd2o/data/00-common/IIoT/IIoT.ipynb)
#
# ### Anbindung der Fachapplikationen
#
# * [IoTKit Board sendet Daten an Fachapplikation mittels HTTP ](../../duk/data/jupyter/functions/order/order.ipynb)
# * [Asynchrone Kommunikation (Data Pipeline)](../../k8sd2o/data/00-common/Serving-Eventing/02-K-native-Broker.ipynb)
#
# ### Machine Learning
#
# * [Asynchrone Kommunikation mittels MQTT für Machine Learning (Python Variante)](../../duk/data/jupyter/functions/mqtt-iot-subscriber/mqtt-iot-subscriber-2.0.0.ipynb)
# * [Asynchrone Kommunikation mittels MQTT für Machine Learning (K-native Variante)](../../k8sd2o/data/00-common/Serving-Eventing/03-K-native-IIoT.ipynb)
# * [ML/IoT Anwendung](../../duk/data/jupyter/mlg/02-2-MLTempHumSensor.ipynb)
# * [Einführung in Machine Learning (Quick Start)](../../duk/data/jupyter/mlg/02-1-QuickStart.ipynb)
